# %%
import os
from shutil import copy2

# %%
path_rad = "D:/data-weather/data_rad_npy_256x256/"
path_sa1 = "D:/data-weather/data_sat_1_npy_256x256/"
path_sa2 = "D:/data-weather/data_sat_2_npy_256x256/"
path_sa3 = "D:/data-weather/data_sat_3_npy_256x256/"
path_sa4 = "D:/data-weather/data_sat_4_npy_256x256/"
path_sa6 = "D:/data-weather/data_sat_6_npy_256x256/"
path_mrh = "D:/data-weather/data_mod_mrh_npy_256x256/"
path_msh = "D:/data-weather/data_mod_msh_npy_256x256/"
path_tem = "D:/data-weather/data_mod_tem_npy_256x256/"
path_vis = "D:/data-weather/data_mod_vis_npy_256x256/"

# %%
list_rad_mmddhh = []
directory = os.fsencode(path_rad)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    #print(filename[8:14])
    mmddhh = filename[8:14]
    list_rad_mmddhh.append(mmddhh)
    
list_sa1_mmddhh = []
directory = os.fsencode(path_sa1)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    #print(filename[8:14])
    mmddhh = filename[8:14]
    list_sa1_mmddhh.append(mmddhh)
    
list_sa2_mmddhh = []
directory = os.fsencode(path_sa2)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    #print(filename[8:14])
    mmddhh = filename[8:14]
    list_sa2_mmddhh.append(mmddhh)
    
list_sa3_mmddhh = []
directory = os.fsencode(path_sa3)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    #print(filename[8:14])
    mmddhh = filename[8:14]
    list_sa3_mmddhh.append(mmddhh)
    
list_sa4_mmddhh = []
directory = os.fsencode(path_sa4)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    #print(filename[8:14])
    mmddhh = filename[8:14]
    list_sa4_mmddhh.append(mmddhh)
    
list_sa6_mmddhh = []
directory = os.fsencode(path_sa6)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    #print(filename[8:14])
    mmddhh = filename[8:14]
    list_sa6_mmddhh.append(mmddhh)
    
list_mrh_mmddhh = []
directory = os.fsencode(path_mrh)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    #print(filename[8:14])
    mmddhh = filename[8:14]
    list_mrh_mmddhh.append(mmddhh)
    
list_msh_mmddhh = []
directory = os.fsencode(path_msh)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    #print(filename[8:14])
    mmddhh = filename[8:14]
    list_msh_mmddhh.append(mmddhh)
    
list_tem_mmddhh = []
directory = os.fsencode(path_tem)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    #print(filename[8:14])
    mmddhh = filename[8:14]
    list_tem_mmddhh.append(mmddhh)
    
list_vis_mmddhh = []
directory = os.fsencode(path_vis)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    #print(filename[8:14])
    mmddhh = filename[8:14]
    list_vis_mmddhh.append(mmddhh)

# %%
print(len(list_rad_mmddhh))
print(len(list_sa1_mmddhh))
print(len(list_sa2_mmddhh))
print(len(list_sa3_mmddhh))
print(len(list_sa4_mmddhh))
print(len(list_sa6_mmddhh))
print(len(list_mrh_mmddhh))
print(len(list_msh_mmddhh))
print(len(list_tem_mmddhh))
print(len(list_vis_mmddhh))

print(list_rad_mmddhh[0])
print(list_sa1_mmddhh[0])
print(list_sa2_mmddhh[0])
print(list_sa3_mmddhh[0])
print(list_sa4_mmddhh[0])
print(list_sa6_mmddhh[0])
print(list_mrh_mmddhh[0])
print(list_msh_mmddhh[0])
print(list_tem_mmddhh[0])
print(list_vis_mmddhh[0])

# %%
list_rad_sa1 = []
for file_1 in list_rad_mmddhh:
    for file_2 in list_sa1_mmddhh:
        if (file_1 == file_2):
            list_rad_sa1.append(file_1)
            break
print(len(list_rad_sa1))

list_rad_sa1_sa2 = []
for file_1 in list_rad_sa1:
    for file_2 in list_sa2_mmddhh:
        if (file_1 == file_2):
            list_rad_sa1_sa2.append(file_1)
            break
print(len(list_rad_sa1_sa2))

list_rad_sa1_sa2_sa3 = []
for file_1 in list_rad_sa1_sa2:
    for file_2 in list_sa3_mmddhh:
        if (file_1 == file_2):
            list_rad_sa1_sa2_sa3.append(file_1)
            break
print(len(list_rad_sa1_sa2_sa3))

list_rad_sa1_sa2_sa3_sa4 = []
for file_1 in list_rad_sa1_sa2_sa3:
    for file_2 in list_sa4_mmddhh:
        if (file_1 == file_2):
            list_rad_sa1_sa2_sa3_sa4.append(file_1)
            break
print(len(list_rad_sa1_sa2_sa3_sa4))

list_rad_sa1_sa2_sa3_sa4_sa6 = []
for file_1 in list_rad_sa1_sa2_sa3_sa4:
    for file_2 in list_sa6_mmddhh:
        if (file_1 == file_2):
            list_rad_sa1_sa2_sa3_sa4_sa6.append(file_1)
            break
print(len(list_rad_sa1_sa2_sa3_sa4_sa6))

list_rad_sa1_sa2_sa3_sa4_sa6_mrh = []
for file_1 in list_rad_sa1_sa2_sa3_sa4_sa6:
    for file_2 in list_mrh_mmddhh:
        if (file_1 == file_2):
            list_rad_sa1_sa2_sa3_sa4_sa6_mrh.append(file_1)
            break
print(len(list_rad_sa1_sa2_sa3_sa4_sa6_mrh))

list_rad_sa1_sa2_sa3_sa4_sa6_mrh_msh = []
for file_1 in list_rad_sa1_sa2_sa3_sa4_sa6_mrh:
    for file_2 in list_msh_mmddhh:
        if (file_1 == file_2):
            list_rad_sa1_sa2_sa3_sa4_sa6_mrh_msh.append(file_1)
            break
print(len(list_rad_sa1_sa2_sa3_sa4_sa6_mrh_msh))

list_rad_sa1_sa2_sa3_sa4_sa6_mrh_msh_tem = []
for file_1 in list_rad_sa1_sa2_sa3_sa4_sa6_mrh_msh:
    for file_2 in list_tem_mmddhh:
        if (file_1 == file_2):
            list_rad_sa1_sa2_sa3_sa4_sa6_mrh_msh_tem.append(file_1)
            break
print(len(list_rad_sa1_sa2_sa3_sa4_sa6_mrh_msh_tem))

list_rad_sa1_sa2_sa3_sa4_sa6_mrh_msh_tem_vis = []
for file_1 in list_rad_sa1_sa2_sa3_sa4_sa6_mrh_msh_tem:
    for file_2 in list_vis_mmddhh:
        if (file_1 == file_2):
            list_rad_sa1_sa2_sa3_sa4_sa6_mrh_msh_tem_vis.append(file_1)
            break
print(len(list_rad_sa1_sa2_sa3_sa4_sa6_mrh_msh_tem_vis))

# %%
path_satyam_rad = "D:/data-weather/member_satyam/satyam_rad_sat_mod_npy/rad_npy/"
path_satyam_sa1 = "D:/data-weather/member_satyam/satyam_rad_sat_mod_npy/sa1_npy/"
path_satyam_sa2 = "D:/data-weather/member_satyam/satyam_rad_sat_mod_npy/sa2_npy/"
path_satyam_sa3 = "D:/data-weather/member_satyam/satyam_rad_sat_mod_npy/sa3_npy/"
path_satyam_sa4 = "D:/data-weather/member_satyam/satyam_rad_sat_mod_npy/sa4_npy/"
path_satyam_sa6 = "D:/data-weather/member_satyam/satyam_rad_sat_mod_npy/sa6_npy/"
path_satyam_mrh = "D:/data-weather/member_satyam/satyam_rad_sat_mod_npy/mrh_npy/"
path_satyam_msh = "D:/data-weather/member_satyam/satyam_rad_sat_mod_npy/msh_npy/"
path_satyam_tem = "D:/data-weather/member_satyam/satyam_rad_sat_mod_npy/tem_npy/"
path_satyam_vis = "D:/data-weather/member_satyam/satyam_rad_sat_mod_npy/vis_npy/"
for mmddhh in list_rad_sa1_sa2_sa3_sa4_sa6_mrh_msh_tem_vis:
    copy2(path_rad+"rad.2017"+mmddhh+".npy",path_satyam_rad+"rad.2017"+mmddhh+".npy")
    copy2(path_sa1+"sat.2017"+mmddhh+".npy",path_satyam_sa1+"sat.2017"+mmddhh+".npy")
    copy2(path_sa2+"sat.2017"+mmddhh+".npy",path_satyam_sa2+"sat.2017"+mmddhh+".npy")
    copy2(path_sa3+"sat.2017"+mmddhh+".npy",path_satyam_sa3+"sat.2017"+mmddhh+".npy")
    copy2(path_sa4+"sat.2017"+mmddhh+".npy",path_satyam_sa4+"sat.2017"+mmddhh+".npy")
    copy2(path_sa6+"sat.2017"+mmddhh+".npy",path_satyam_sa6+"sat.2017"+mmddhh+".npy")
    copy2(path_mrh+"nam.2017"+mmddhh+".npy",path_satyam_mrh+"mod.2017"+mmddhh+".npy")
    copy2(path_msh+"nam.2017"+mmddhh+".npy",path_satyam_msh+"mod.2017"+mmddhh+".npy")
    copy2(path_tem+"nam.2017"+mmddhh+".npy",path_satyam_tem+"mod.2017"+mmddhh+".npy")
    copy2(path_vis+"nam.2017"+mmddhh+".npy",path_satyam_vis+"mod.2017"+mmddhh+".npy")

# %%
path_satyam_sa1 = "D:/data-weather/member_satyam/satyam_rad_sat_mod_npy/sa1_npy/"
path_satyam_sa1_removed = "D:/data-weather/member_satyam/satyam_rad_sat_mod_npy/sa1_npy_removed//"
directory = os.fsencode(path_satyam_sa1)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    #print(filename[12:14])
    if (filename[12:14] == "16" or filename[12:14] == "17" or filename[12:14] == "18" or filename[12:14] == "19" or filename[12:14] == "20"):
        os.rename(path_satyam_sa1+filename, path_satyam_sa1_removed+filename)
