# %%
import os
from shutil import copy2
import numpy as np
import matplotlib.pyplot as plt
import pygrib
from mpl_toolkits.basemap import Basemap
from netCDF4 import Dataset
from PIL import Image
import datetime

# %%
path = "/mnt/data-weather/satraw/band2346/"
path_out = "/mnt/data-weather/satdata/6/"
band = "06"
rex = []
directory = os.fsencode(path)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if (filename[28:30] == band):
        rex.append(filename)
print(rex[0])
print(len(rex))
rex_2 = []
for file in rex:
    if (file[18:20]=="15"):
        rex_2.append(file)
print(rex_2[0])
print(len(rex_2))
rex_3 = []
for file in rex_2:
    hour = file[16:18]
    day = file[12:15]
    out = "sat.2017"+day+"."+hour+".nc"
    rex_3.append(out)
print(rex_3[0])
print(len(rex_3))
rex_4 = []
for file in rex_3:
    day = int(file[8:11])
    time = datetime.datetime(2017, 1, 1) + datetime.timedelta(day - 1)
    if (time.month < 10 and time.day < 10):
        out = "0"+str(time.month)+"0"+str(time.day)
    elif (time.month >= 10 and time.day < 10):
        out = str(time.month)+"0"+str(time.day)
    elif (time.month < 10 and time.day >= 10):
        out = "0"+str(time.month)+str(time.day)
    else:
        out = str(time.month)+str(time.day)
    rex_4.append("sat.2017"+out+file[11:])
print(rex_4[0])
print(len(rex_4))
for i in range(0,len(rex_4)):
    #copy2(path+rex_2[i],path_out+rex_4[i])

# %%
mod_path = "/mnt/data-weather/moddata/"
rad_path = "/mnt/data-weather/raddata/"
sa2_path = "/mnt/data-weather/satdata/3/"
sa6_path = "/mnt/data-weather/satdata/4/"

# %%
mod_dir = os.fsencode(mod_path)
rad_dir = os.fsencode(rad_path)
sa2_dir = os.fsencode(sa2_path)
sa6_dir = os.fsencode(sa6_path)

# %%
mod_full_list = []
rad_full_list = []
sa2_full_list = []
sa6_full_list = []

for file in os.listdir(mod_dir):
    filename = os.fsdecode(file)
    mod_full_list.append(filename)
    
for file in os.listdir(rad_dir):
    filename = os.fsdecode(file)
    rad_full_list.append(filename)
    
for file in os.listdir(sa2_dir):
    filename = os.fsdecode(file)
    sa2_full_list.append(filename)
    
for file in os.listdir(sa6_dir):
    filename = os.fsdecode(file)
    sa6_full_list.append(filename)

# %%
print(mod_full_list[0])
print(len(mod_full_list))
print(rad_full_list[0])
print(len(rad_full_list))
print(sa2_full_list[0])
print(len(sa2_full_list))
print(sa6_full_list[0])
print(len(sa6_full_list))

# %%
sa6_0 = []

for sa2 in sa2_full_list:
    for sa6 in sa6_full_list:
        if (sa6[8:15] == sa2[8:15]):
            sa6_0.append(sa6)
            break
print(len(sa6_0))

sa6_1 = []
for mod in mod_full_list:
    for sa6 in sa6_0:
        if (sa6[8:15] == mod[8:15]):
            sa6_1.append(sa6)
            break
print(len(sa6_1))

sa6_2 = []
for rad in mod_full_list:
    for sa6 in sa6_1:
        if (sa6[8:15] == rad[8:15]):
            sa6_2.append(sa6)
            break
print(len(sa6_2))

# %%
mod_cut_list = []
rad_cut_list = []
sa2_cut_list = []
sa6_cut_list = sa6_2

for corr in sa6_2:
    for mod in mod_full_list:
        if (corr[8:15] == mod[8:15]):
            mod_cut_list.append(mod)
            break
            
for corr in sa6_2:
    for rad in rad_full_list:
        if (corr[8:15] == rad[8:15]):
            rad_cut_list.append(rad)
            break
            
for corr in sa6_2:
    for sa2 in sa2_full_list:
        if (corr[8:15] == sa2[8:15]):
            sa2_cut_list.append(sa2)
            break

# %%
print(len(mod_cut_list))
print(len(rad_cut_list))
print(len(sa2_cut_list))
print(len(sa6_cut_list))

# %%
mod_cut_list_2 = []
rad_cut_list_2 = rad_cut_list
sa2_cut_list_2 = []
sa6_cut_list_2 = []

for corr in rad_cut_list:
    for mod in mod_cut_list:
        if (corr[8:15] == mod[8:15]):
            mod_cut_list_2.append(mod)
            break
            
for corr in rad_cut_list:
    for sa2 in sa2_cut_list:
        if (corr[8:15] == sa2[8:15]):
            sa2_cut_list_2.append(sa2)
            break
            
for corr in rad_cut_list:
    for sa6 in sa6_full_list:
        if (corr[8:15] == sa6[8:15]):
            sa6_cut_list_2.append(sa6)
            break

# %%
print(len(mod_cut_list_2))
print(len(rad_cut_list_2))
print(len(sa2_cut_list_2))
print(len(sa6_cut_list_2))

# %%
#mod_path = "/mnt/data-weather/moddata/"
#rad_path = "/mnt/data-weather/raddata/"
sa2_path = "/mnt/data-weather/satdata/3/"
sa6_path = "/mnt/data-weather/satdata/4/"
#mod_out = "/mnt/data-weather/final2/mod/"
#rad_out = "/mnt/data-weather/final2/rad/"
sa2_out = "/mnt/data-weather/final2/sa3/"
sa6_out = "/mnt/data-weather/final2/sa4/"

#for file in mod_cut_list_2:
    #copy2(mod_path+file,mod_out+file)
#for file in rad_cut_list_2:
    #copy2(rad_path+file,rad_out+file)
for file in sa2_cut_list_2:
    copy2(sa2_path+file,sa2_out+file)
for file in sa6_cut_list_2:
    copy2(sa6_path+file,sa6_out+file)

# %%
mo0_path = "/mnt/data-weather/moddata/band1236/"
directory = os.fsencode(mo0_path)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    #print(filename)
    #print(filename[13:15])
    #if (filename[13:15] == "24"):
    #    out = mo0_path+filename[0:13]+"22"+filename[15:]
    #    print(out)
    #    os.rename(mo0_path+filename,out)

# %%
path = "/mnt/data-weather/moddata/band0/"
directory = os.fsencode(path)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    print(path+filename)
    out = path+filename[0:15]+filename[18:]
    print(out)
    #os.rename(path+filename,out)

# %%
mod_path = "/mnt/data-weather/moddata/band1236/"
rad_path = "/mnt/data-weather/corr/mod/band0/raddat/"
sa2_path = "/mnt/data-weather/corr/sat/band3/"
sa6_path = "/mnt/data-weather/corr/sat/band4/"

# %%
# list of paths to all the data that needs to be correlated
mod_path = "/mnt/data-weather/corr/mod/band0/modgrb/"
rad_path = "/mnt/data-weather/corr/mod/band0/raddat/"
sa2_path = "/mnt/data-weather/corr/sat/band2/"
sa6_path = "/mnt/data-weather/corr/sat/band6/"

# %%
mod_filenames = []
rad_filenames = []
sa2_filenames = []
sa6_filenames = []

directory = os.fsencode(mod_path)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    mod_filenames.append(filename)

directory = os.fsencode(rad_path)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    rad_filenames.append(filename)

directory = os.fsencode(sa2_path)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    sa2_filenames.append(filename)
    
directory = os.fsencode(sa6_path)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    sa6_filenames.append(filename)

# %%
print(mod_filenames[0])
print(sa2_filenames[0])
print(sa6_filenames[0])
print(rad_filenames[0])

# %%
mod_corr = []
sa2_corr = []
sa6_corr = []
rad_corr = []

temp = []

print(len(mod_filenames))
print(len(sa2_filenames))
print(len(sa6_filenames))
print(len(rad_filenames))

for sa2 in sa2_filenames:
    for rad in rad_filenames:
        if (rad[8:15]==sa2[8:15]):
            temp.append(rad)
            break

# %%
temp2 = []
for sa6 in sa6_filenames:
    for t in temp:
        if (t[8:15]==sa6[8:15]):
            temp2.append(t)
            break

# %%
#print(temp2)
mod_corr = []
sa2_corr = []
sa6_corr = []
rad_corr = []
for t in temp2:
    for mod in mod_filenames:
        if (t[8:15]==mod[8:15]):
            mod_corr.append(mod)
    for sa2 in sa2_filenames:
        if (t[8:15]==sa2[8:15]):
            sa2_corr.append(sa2)
    for sa6 in sa6_filenames:
        if (t[8:15]==sa6[8:15]):
            sa6_corr.append(sa6)
    for rad in rad_filenames:
        if (t[8:15]==rad[8:15]):
            rad_corr.append(rad)

# %%
print(len(mod_corr), len(sa2_corr), len(sa6_corr), len(rad_corr))
print(mod_corr[0])

# %%
new_mod = "/mnt/data-weather/final/mod/"
new_sa2 = "/mnt/data-weather/final/sa2/"
new_sa6 = "/mnt/data-weather/final/sa6/"
new_rad = "/mnt/data-weather/final/rad/"

for mod in mod_corr:
    copy2(mod_path+mod,new_mod+mod)

for sa2 in sa2_corr:
    copy2(sa2_path+sa2,new_sa2+sa2)
    
for sa6 in sa6_corr:
    copy2(sa6_path+sa6,new_sa6+sa6)
    
for rad in rad_corr:
    copy2(rad_path+rad,new_rad+rad)

# %%
# radar data to radar png 
path = "/mnt/data-weather/final2/rad/"
out = "/mnt/data-weather/final2/radpng/"
directory = os.fsencode(path)
dims = (126,201)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    newname = out+filename[0:15]+".png"
    print(newname)
    data = np.fromfile(path+filename,dtype='int16',count=-1,sep='') # 2 byte integers
    data = np.reshape(data,dims)
    fig = plt.figure(figsize=(9,9))
    plt.axis('off')
    plt.imshow(data, cmap='gray', origin='lower')
    fig.savefig(newname,bbox_inches='tight',pad_inches=-0.36)
    plt.close(fig)

# %%
# RUN ME
path = "/mnt/data-weather/final2/mod/"
out = "/mnt/data-weather/final2/modpng/SH/"
directory = os.fsencode(path)
feature = "Specific humidity"
m = Basemap(projection='mill',
            llcrnrlon=-102.0,
            urcrnrlon=-82.0,
            llcrnrlat=31.0,
            urcrnrlat=41.0,
            resolution='l')
rex = 0
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    newname = out+filename[0:15]+".SH.png"
    print(newname)
    grbs = pygrib.open(path+filename)
    grb = grbs.select(name=feature)[0]
    grbs.close()
    data = grb.values
    if (rex == 0):
        lat, lon = grb.latlons()
        x, y = m(lon,lat)
        rex += 1
    plt.figure(figsize=(9,9))
    m.pcolormesh(x,y,data,shading='flat',cmap="gray")
    plt.savefig(newname, bbox_inches="tight", pad_inches=-0.1)
    plt.clf()
    plt.close()

# %%
path = "/mnt/data-weather/final/mod/"
out = "/mnt/data-weather/final/modpng/T/"
directory = os.fsencode(path)
feature = "Temperature"
m = Basemap(projection='mill',
            llcrnrlon=-102.0,
            urcrnrlon=-82.0,
            llcrnrlat=31.0,
            urcrnrlat=41.0,
            resolution='l')
rex = 0
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    newname = out+filename[0:18]+".T.png"
    print(newname)
    grbs = pygrib.open(path+filename)
    grb = grbs.select(name=feature)[0]
    grbs.close()
    data = grb.values
    if (rex == 0):
        lat, lon = grb.latlons()
        x, y = m(lon,lat)
        rex += 1
    plt.figure(figsize=(9,9))
    m.pcolormesh(x,y,data,shading='flat',cmap="gray")
    plt.savefig(newname, bbox_inches="tight", pad_inches=-0.1)
    plt.clf()
    plt.close()

# %%
path = "/mnt/data-weather/final/mod/"
out = "/mnt/data-weather/final/modpng/V/"
directory = os.fsencode(path)
feature = "Visibility"
m = Basemap(projection='mill',
            llcrnrlon=-102.0,
            urcrnrlon=-82.0,
            llcrnrlat=31.0,
            urcrnrlat=41.0,
            resolution='l')
rex = 0
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    newname = out+filename[0:18]+".V.png"
    print(newname)
    grbs = pygrib.open(path+filename)
    grb = grbs.select(name=feature)[0]
    grbs.close()
    data = grb.values
    if (rex == 0):
        lat, lon = grb.latlons()
        x, y = m(lon,lat)
        rex += 1
    plt.figure(figsize=(9,9))
    m.pcolormesh(x,y,data,shading='flat',cmap="gray")
    plt.savefig(newname, bbox_inches="tight", pad_inches=-0.1)
    plt.clf()
    plt.close()

# %%
path = "/mnt/data-weather/final/mod/"
out = "/mnt/data-weather/final/modpng/TP/"
directory = os.fsencode(path)
feature = "Total Precipitation"
m = Basemap(projection='mill',
            llcrnrlon=-102.0,
            urcrnrlon=-82.0,
            llcrnrlat=31.0,
            urcrnrlat=41.0,
            resolution='l')
rex = 0
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    newname = out+filename[0:18]+".TP.png"
    print(newname)
    grbs = pygrib.open(path+filename)
    grb = grbs.select(name=feature)[0]
    grbs.close()
    data = grb.values
    if (rex == 0):
        lat, lon = grb.latlons()
        x, y = m(lon,lat)
        rex += 1
    plt.figure(figsize=(9,9))
    m.pcolormesh(x,y,data,shading='flat',cmap="gray")
    plt.savefig(newname, bbox_inches="tight", pad_inches=-0.1)
    plt.clf()
    plt.close()

# %%
path = "/mnt/data-weather/final/mod/"
out = "/mnt/data-weather/final/modpng/SH/"
directory = os.fsencode(path)
feature = "Specific humidity"
m = Basemap(projection='mill',
            llcrnrlon=-102.0,
            urcrnrlon=-82.0,
            llcrnrlat=31.0,
            urcrnrlat=41.0,
            resolution='l')
rex = 0
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    newname = out+filename[0:18]+".SH.png"
    print(newname)
    grbs = pygrib.open(path+filename)
    grb = grbs.select(name=feature)[0]
    grbs.close()
    data = grb.values
    if (rex == 0):
        lat, lon = grb.latlons()
        x, y = m(lon,lat)
        rex += 1
    plt.figure(figsize=(9,9))
    m.pcolormesh(x,y,data,shading='flat',cmap="gray")
    plt.savefig(newname, bbox_inches="tight", pad_inches=-0.1)
    plt.clf()
    plt.close()

# %%
path = "/mnt/data-weather/final2/sa4/"
out = "/mnt/data-weather/final2/sa4png/"
directory = os.fsencode(path)
m = Basemap(projection='mill',
            llcrnrlon=-102.0,
            urcrnrlon=-82.0,
            llcrnrlat=31.0,
            urcrnrlat=41.0,
            resolution='l')
rex = 0
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    newname = out+filename[0:15]+".png"
    print(newname)
    nc_fid = Dataset(path+filename, 'r')
    data = nc_fid.variables['data'][0][:]
    if (rex == 0):
        lat = nc_fid.variables['lat'][:]
        lon = nc_fid.variables['lon'][:]
        x, y = m(lon,lat)
        rex += 1
    print(data.shape, lat.shape, lon.shape)
    nc_fid.close()
    plt.figure(figsize=(9,9))
    m.pcolormesh(x,y,data,shading='flat',cmap="gray")
    plt.savefig(newname, bbox_inches="tight", pad_inches=-0.1)
    plt.clf()
    plt.close()

# %%
path = "/mnt/data-weather/final/sa6/"
out = "/mnt/data-weather/final/sa6png/"
directory = os.fsencode(path)
m = Basemap(projection='mill',
            llcrnrlon=-102.0,
            urcrnrlon=-82.0,
            llcrnrlat=31.0,
            urcrnrlat=41.0,
            resolution='l')
rex = 0
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    newname = out+filename[0:18]+".png"
    print(newname)
    nc_fid = Dataset(path+filename, 'r')
    data = nc_fid.variables['data'][0][:]
    if (rex == 0):
        lat = nc_fid.variables['lat'][:]
        lon = nc_fid.variables['lon'][:]
        x, y = m(lon,lat)
        rex += 1
    nc_fid.close()
    plt.figure(figsize=(9,9))
    m.pcolormesh(x,y,data,shading='flat',cmap="gray")
    plt.savefig(newname, bbox_inches="tight", pad_inches=-0.1)
    plt.clf()
    plt.close()

# %%
# code used to resize png images to 256x256
indirectory = "/mnt/data-weather/final2/modpng/V/"
outdirectory = "/mnt/data-weather/final2/modresize/V/"
directory = os.fsencode(indirectory)
size = 256, 256
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    img = Image.open(indirectory+filename)
    img = img.resize((size), Image.ANTIALIAS)
    img.save(outdirectory+filename)

# %%
# code used to resize png images to 256x256
indirectory = "/mnt/data-weather/final2/modpng/RH/"
outdirectory = "/mnt/data-weather/final2/modresize/RH/"
directory = os.fsencode(indirectory)
size = 256, 256
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    img = Image.open(indirectory+filename)
    img = img.resize((size), Image.ANTIALIAS)
    img.save(outdirectory+filename)

# %%
# code used to resize png images to 256x256
indirectory = "/mnt/data-weather/final2/modpng/SH/"
outdirectory = "/mnt/data-weather/final2/modresize/SH/"
directory = os.fsencode(indirectory)
size = 256, 256
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    img = Image.open(indirectory+filename)
    img = img.resize((size), Image.ANTIALIAS)
    img.save(outdirectory+filename)

# %%
# code used to resize png images to 256x256
indirectory = "/mnt/data-weather/final2/modpng/T/"
outdirectory = "/mnt/data-weather/final2/modresize/T/"
directory = os.fsencode(indirectory)
size = 256, 256
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    img = Image.open(indirectory+filename)
    img = img.resize((size), Image.ANTIALIAS)
    img.save(outdirectory+filename)

# %%
# code used to resize png images to 256x256
indirectory = "/mnt/data-weather/final2/radpng/"
outdirectory = "/mnt/data-weather/final2/radresize/"
directory = os.fsencode(indirectory)
size = 256, 256
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    img = Image.open(indirectory+filename)
    img = img.resize((size), Image.ANTIALIAS)
    img.save(outdirectory+filename)

# %%
# code used to resize png images to 256x256
indirectory = "/mnt/data-weather/final2/sa2png/"
outdirectory = "/mnt/data-weather/final2/sa2resize/"
directory = os.fsencode(indirectory)
size = 256, 256
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    img = Image.open(indirectory+filename)
    img = img.resize((size), Image.ANTIALIAS)
    img.save(outdirectory+filename)

# %%
# code used to resize png images to 256x256
indirectory = "/mnt/data-weather/final2/sa4png/"
outdirectory = "/mnt/data-weather/final2/sa4resize/"
directory = os.fsencode(indirectory)
size = 256, 256
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    img = Image.open(indirectory+filename)
    img = img.resize((size), Image.ANTIALIAS)
    img.save(outdirectory+filename)

# %%
indirectory = "/mnt/data-weather/final2/sa2resize/"
outdirectory = "/mnt/data-weather/final2/A/"
directory = os.fsencode(indirectory)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    print(filename)
    copy2(indirectory+filename,outdirectory+filename[8:12]+filename[13:15]+"A1.png")

# %%
indirectory = "/mnt/data-weather/final2/sa3resize/"
outdirectory = "/mnt/data-weather/final2/A/"
directory = os.fsencode(indirectory)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    print(filename)
    copy2(indirectory+filename,outdirectory+filename[8:12]+filename[13:15]+"A2.png")

# %%
indirectory = "/mnt/data-weather/final2/sa4resize/"
outdirectory = "/mnt/data-weather/final2/A/"
directory = os.fsencode(indirectory)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    print(filename)
    copy2(indirectory+filename,outdirectory+filename[8:12]+filename[13:15]+"A3.png")

# %%
indirectory = "/mnt/data-weather/final2/sa6resize/"
outdirectory = "/mnt/data-weather/final2/A/"
directory = os.fsencode(indirectory)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    print(filename)
    copy2(indirectory+filename,outdirectory+filename[8:12]+filename[13:15]+"A4.png")

# %%
indirectory = "/mnt/data-weather/final2/modresize/V/"
outdirectory = "/mnt/data-weather/final2/A/"
directory = os.fsencode(indirectory)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    print(filename)
    copy2(indirectory+filename,outdirectory+filename[8:12]+filename[13:15]+"A3.png")

# %%
indirectory = "/mnt/data-weather/final2/modresize/RH/"
outdirectory = "/mnt/data-weather/final2/A/"
directory = os.fsencode(indirectory)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    print(filename)
    copy2(indirectory+filename,outdirectory+filename[8:12]+filename[13:15]+"A4.png")

# %%
indirectory = "/mnt/data-weather/final2/modresize/SH/"
outdirectory = "/mnt/data-weather/final2/A/"
directory = os.fsencode(indirectory)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    print(filename)
    copy2(indirectory+filename,outdirectory+filename[8:12]+filename[13:15]+"A5.png")

# %%
indirectory = "/mnt/data-weather/final2/modresize/T/"
outdirectory = "/mnt/data-weather/final2/A/"
directory = os.fsencode(indirectory)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    print(filename)
    copy2(indirectory+filename,outdirectory+filename[8:12]+filename[13:15]+"A6.png")

# %%
indirectory = "/mnt/data-weather/final2/radresize/"
outdirectory = "/mnt/data-weather/final2/B/"
directory = os.fsencode(indirectory)
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    print(filename)
    copy2(indirectory+filename,outdirectory+filename[8:12]+filename[13:15]+"B1.png")
    #copy2(indirectory+filename,outdirectory+filename[8:12]+filename[13:15]+"B2.png")
    #copy2(indirectory+filename,outdirectory+filename[8:12]+filename[13:15]+"B3.png")
    #copy2(indirectory+filename,outdirectory+filename[8:12]+filename[13:15]+"B4.png")
    #copy2(indirectory+filename,outdirectory+filename[8:12]+filename[13:15]+"B5.png")
    #copy2(indirectory+filename,outdirectory+filename[8:12]+filename[13:15]+"B6.png")

# %%
file = "/mnt/data-weather/moddata/band0/nam.20171231.18.00.grb2"
grbs = pygrib.open(file)
for grb in grbs:
    print(grb)
grbs.close()
