# %%
import os
import numpy as np
import pygrib

# %%
# let's view the list of features
grbs = pygrib.open("/mnt/data-weather/moddata/modgrb/namanl_218_20170101_0000_000.grb")
#for grb in grbs:
#    print(grb)
grb = grbs.select(name="Relative humidity")[0]
data = grb.values
print(value.shape)
lats, lons = grb.latlons()
print(lats.shape, lons.shape)
data, lats, lons = grb.data(lat1 = 31, lat2 = 41, lon1 = -102, lon2 = -82)
print(data.shape, lats.shape, lons.shape)
print(data.max())
grbs.close()
# Out:
# (428, 614)
# (428, 614) (428, 614)
# (13984,) (13984,) (13984,)
# 100.0

# %%
# let's view the list of features
grbs = pygrib.open("/mnt/data-weather/moddata/modgrb/namanl_218_20171201_0000_000.grb2")
for grb in grbs:
    print(grb)
grbs.close()
# Out:
# 1:Pressure reduced to MSL:Pa (instant):lambert:meanSea:level 0:fcst time 0 hrs:from 201712010000
# 2:Derived radar reflectivity:dB (instant):lambert:hybrid:level 1:fcst time 0 hrs:from 201712010000
# 3:Maximum/Composite radar reflectivity:dB (instant):lambert:unknown:level 0 considered as a single layer:fcst time 0 hrs:from 201712010000
# 4:Visibility:m (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 5:Visibility:m (instant):lambert:cloudTop:level 0:fcst time 0 hrs:from 201712010000
# 6:Blackadar mixing length scale:m (instant):lambert:hybrid:level 1:fcst time 0 hrs:from 201712010000
# 7:Geopotential Height:gpm (instant):lambert:unknown:level 0:fcst time 0 hrs:from 201712010000
# 8:U component of wind:m s**-1 (instant):lambert:unknown:level 0:fcst time 0 hrs:from 201712010000
# 9:V component of wind:m s**-1 (instant):lambert:unknown:level 0:fcst time 0 hrs:from 201712010000
# 10:Ventilation Rate:m**2 s**-1 (instant):lambert:unknown:level 0:fcst time 0 hrs:from 201712010000
# 11:Wind speed (gust):m s**-1 (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 12:197:197 (instant):lambert:unknown:level 0 considered as a single layer:fcst time 0 hrs:from 201712010000
# 13:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 500 Pa:fcst time 0 hrs:from 201712010000
# 14:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 1000 Pa:fcst time 0 hrs:from 201712010000
# 15:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 2000 Pa:fcst time 0 hrs:from 201712010000
# 16:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201712010000
# 17:Temperature:K (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201712010000
# 18:Relative humidity:% (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201712010000
# 19:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201712010000
# 20:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201712010000
# 21:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201712010000
# 22:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201712010000
# 23:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201712010000
# 24:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 7500 Pa:fcst time 0 hrs:from 201712010000
# 25:Temperature:K (instant):lambert:isobaricInhPa:level 7500 Pa:fcst time 0 hrs:from 201712010000
# 26:Relative humidity:% (instant):lambert:isobaricInhPa:level 7500 Pa:fcst time 0 hrs:from 201712010000
# 27:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 7500 Pa:fcst time 0 hrs:from 201712010000
# 28:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 7500 Pa:fcst time 0 hrs:from 201712010000
# 29:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 7500 Pa:fcst time 0 hrs:from 201712010000
# 30:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 7500 Pa:fcst time 0 hrs:from 201712010000
# 31:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 7500 Pa:fcst time 0 hrs:from 201712010000
# 32:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201712010000
# 33:Temperature:K (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201712010000
# 34:Relative humidity:% (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201712010000
# 35:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201712010000
# 36:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201712010000
# 37:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201712010000
# 38:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201712010000
# 39:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201712010000
# 40:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 0 hrs:from 201712010000
# 41:Temperature:K (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 0 hrs:from 201712010000
# 42:Relative humidity:% (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 0 hrs:from 201712010000
# 43:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 0 hrs:from 201712010000
# 44:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 0 hrs:from 201712010000
# 45:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 0 hrs:from 201712010000
# 46:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 0 hrs:from 201712010000
# 47:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time
V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 85000 Pa:fcst time 0 hrs:from 201712010000
# 282:Absolute vorticity:s**-1 (instant):lambert:isobaricInhPa:level 85000 Pa:fcst time 0 hrs:from 201712010000
# 283:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 85000 Pa:fcst time 0 hrs:from 201712010000
# 284:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 87500 Pa:fcst time 0 hrs:from 201712010000
# 285:Temperature:K (instant):lambert:isobaricInhPa:level 87500 Pa:fcst time 0 hrs:from 201712010000
# 286:Relative humidity:% (instant):lambert:isobaricInhPa:level 87500 Pa:fcst time 0 hrs:from 201712010000
# 287:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 87500 Pa:fcst time 0 hrs:from 201712010000
# 288:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 87500 Pa:fcst time 0 hrs:from 201712010000
# 289:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 87500 Pa:fcst time 0 hrs:from 201712010000
# 290:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 87500 Pa:fcst time 0 hrs:from 201712010000
# 291:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 87500 Pa:fcst time 0 hrs:from 201712010000
# 292:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 90000 Pa:fcst time 0 hrs:from 201712010000
# 293:Temperature:K (instant):lambert:isobaricInhPa:level 90000 Pa:fcst time 0 hrs:from 201712010000
# 294:Relative humidity:% (instant):lambert:isobaricInhPa:level 90000 Pa:fcst time 0 hrs:from 201712010000
# 295:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 90000 Pa:fcst time 0 hrs:from 201712010000
# 296:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 90000 Pa:fcst time 0 hrs:from 201712010000
# 297:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 90000 Pa:fcst time 0 hrs:from 201712010000
# 298:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 90000 Pa:fcst time 0 hrs:from 201712010000
# 299:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 90000 Pa:fcst time 0 hrs:from 201712010000
# 300:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 201712010000
# 301:Temperature:K (instant):lambert:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 201712010000
# 302:Relative humidity:% (instant):lambert:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 201712010000
# 303:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 201712010000
# 304:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 201712010000
# 305:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 201712010000
# 306:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 201712010000
# 307:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 201712010000
# 308:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 95000 Pa:fcst time 0 hrs:from 201712010000
# 309:Temperature:K (instant):lambert:isobaricInhPa:level 95000 Pa:fcst time 0 hrs:from 201712010000
# 310:Relative humidity:% (instant):lambert:isobaricInhPa:level 95000 Pa:fcst time 0 hrs:from 201712010000
# 311:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 95000 Pa:fcst time 0 hrs:from 201712010000
# 312:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 95000 Pa:fcst time 0 hrs:from 201712010000
# 313:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 95000 Pa:fcst time 0 hrs:from 201712010000
# 314:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 95000 Pa:fcst time 0 hrs:from 201712010000
# 315:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 95000 Pa:fcst time 0 hrs:from 201712010000
# 316:Haines Index:Numeric (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 317:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 97500 Pa:fcst time 0 hrs:from 201712010000
# 318:Temperature:K (instant):lambert:isobaricInhPa:level 97500 Pa:fcst time 0 hrs:from 201712010000
# 319:Relative humidity:% (instant):lambert:isobaricInhPa:level 97500 Pa:fcst time 0 hrs:from 201712010000
# 320:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 97500 Pa:fcst time 0 hrs:from 201712010000
# 321:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 97500 Pa:fcst time 0 hrs:from 201712010000
# 322:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 97500 Pa:fcst time 0 hrs:from 201712010000
# 323:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 97500 Pa:fcst time 0 hrs:from 201712010000
# 324:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 97500 Pa:fcst time 0 hrs:from 201712010000
# 325:Temperature:K (instant):lambert:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201712010000
# 326:Relative humidity:% (instant):lambert:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201712010000
# 327:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201712010000
# 328:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201712010000
# 329:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201712010000
# 330:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201712010000
# 331:Absolute vorticity:s**-1 (instant):lambert:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201712010000
# 332:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201712010000
# 333:MSLP (Eta model reduction):Pa (instant):lambert:meanSea:level 0:fcst time 0 hrs:from 201712010000
# 334:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201712010000
# 335:Derived radar reflectivity:dB (instant):lambert:heightAboveGround:level 4000 m:fcst time 0 hrs:from 201712010000
# 336:Derived radar reflectivity:dB (instant):lambert:heightAboveGround:level 1000 m:fcst time 0 hrs:from 201712010000
# 337:Surface pressure:Pa (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 338:Orography:m (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 339:Temperature:K (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 340:Soil Temperature:K (instant):lambert:depthBelowLandLayer:levels 0.0-0.1 m:fcst time 0 hrs:from 201712010000
# 341:Volumetric soil moisture content:Proportion (instant):lambert:depthBelowLandLayer:levels 0.0-0.1 m:fcst time 0 hrs:from 201712010000
# 342:Liquid volumetric soil moisture (non-frozen):Proportion (instant):lambert:depthBelowLandLayer:levels 0.0-0.1 m:fcst time 0 hrs:from 201712010000
# 343:Soil Temperature:K (instant):lambert:depthBelowLandLayer:levels 0.1-0.4 m:fcst time 0 hrs:from 201712010000
# 344:Volumetric soil moisture content:Proportion (instant):lambert:depthBelowLandLayer:levels 0.1-0.4 m:fcst time 0 hrs:from 201712010000
# 345:Liquid volumetric soil moisture (non-frozen):Proportion (instant):lambert:depthBelowLandLayer:levels 0.1-0.4 m:fcst time 0 hrs:from 201712010000
# 346:Soil Temperature:K (instant):lambert:depthBelowLandLayer:levels 0.4-1.0 m:fcst time 0 hrs:from 201712010000
# 347:Volumetric soil moisture content:Proportion (instant):lambert:depthBelowLandLayer:levels 0.4-1.0 m:fcst time 0 hrs:from 201712010000
# 348:Liquid volumetric soil moisture (non-frozen):Proportion (instant):lambert:depthBelowLandLayer:levels 0.4-1.0 m:fcst time 0 hrs:from 201712010000
# 349:Soil Temperature:K (instant):lambert:depthBelowLandLayer:levels 1.0-2.0 m:fcst time 0 hrs:from 201712010000
# 350:Volumetric soil moisture content:Proportion (instant):lambert:depthBelowLandLayer:levels 1.0-2.0 m:fcst time 0 hrs:from 201712010000
# 351:Liquid volumetric soil moisture (non-frozen):Proportion (instant):lambert:depthBelowLandLayer:levels 1.0-2.0 m:fcst time 0 hrs:from 201712010000
# 352:Soil Temperature:K (instant):lambert:depthBelowLand:level 3 m:fcst time 0 hrs:from 201712010000
# 353:Moisture availability:% (instant):lambert:depthBelowLandLayer:levels 0.0-1.0 m:fcst time 0 hrs:from 201712010000
# 354:Soil moisture content:kg m**-2 (instant):lambert:depthBelowLandLayer:levels 0.0-2.0 m:fcst time 0 hrs:from 201712010000
# 355:Plant canopy surface water:kg m**-2 (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 356:Water equivalent of accumulated snow depth:kg m**-2 (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 357:Snow cover:% (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 358:Snow depth:m (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 359:Direct evaporation cease (soil moisture):Proportion (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 360:Soil porosity:Proportion (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 361:2 metre temperature:K (instant):lambert:heightAboveGround:level 2 m:fcst time 0 hrs:from 201712010000
# 362:Specific humidity:kg kg**-1 (instant):lambert:heightAboveGround:level 2 m:fcst time 0 hrs:from 201712010000
# 363:2 metre dewpoint temperature:K (instant):lambert:heightAboveGround:level 2 m:fcst time 0 hrs:from 201712010000
# 364:2 metre relative humidity:% (instant):lambert:heightAboveGround:level 2 m:fcst time 0 hrs:from 201712010000
# 365:10 metre U wind component:m s**-1 (instant):lambert:heightAboveGround:level 10 m:fcst time 0 hrs:from 201712010000
# 366:10 metre V wind component:m s**-1 (instant):lambert:heightAboveGround:level 10 m:fcst time 0 hrs:from 201712010000
# 367:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0 hrs (accum):from 201712010000
# 368:Convective precipitation (water):kg m**-2 (accum):lambert:surface:level 0:fcst time 0 hrs (accum):from 201712010000
# 369:Water equivalent of accumulated snow depth:kg m**-2 (accum):lambert:surface:level 0:fcst time 0 hrs (accum):from 201712010000
# 370:Geopotential Height:gpm (instant):lambert:unknown:level 0 245:fcst time 0 hrs:from 201712010000
# 371:Categorical snow:(Code table 4.222) (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 372:Categorical ice pellets:(Code table 4.222) (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 373:Categorical freezing rain:(Code table 4.222) (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 374:Categorical rain:(Code table 4.222) (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 375:Surface roughness:m (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 376:Frictional velocity:m s**-1 (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 377:Drag coefficient:Numeric (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 378:Vegetation:% (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 379:Vegetation Type:Integer(0-13) (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 380:Soil type:~ (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 381:Number of soil layers in root zone:Numeric (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 382:Wilting Point:Fraction (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 383:Transpiration stress-onset (soil moisture):Proportion (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 384:Surface lifted index:K (instant):lambert:isobaricLayer:levels 50000-100000 Pa:fcst time 0 hrs:from 201712010000
# 385:Convective available potential energy:J kg**-1 (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 386:Convective inhibition:J kg**-1 (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 387:Precipitable water:kg m**-2 (instant):lambert:unknown:level 0 considered as a single layer:fcst time 0 hrs:from 201712010000
# 388:Geopotential Height:gpm (instant):lambert:cloudBase:level 0:fcst time 0 hrs:from 201712010000
# 389:Storm relative helicity:J kg**-1 (instant):lambert:heightAboveGroundLayer:levels 3000-0 m:fcst time 0 hrs:from 201712010000
# 390:Vertical u-component shear:s**-1 (instant):lambert:heightAboveGroundLayer:levels 0-6000 m:fcst time 0 hrs:from 201712010000
# 391:Vertical v-component shear:s**-1 (instant):lambert:heightAboveGroundLayer:levels 0-6000 m:fcst time 0 hrs:from 201712010000
# 392:Pressure:Pa (instant):lambert:tropopause:level 0:fcst time 0 hrs:from 201712010000
# 393:Temperature:K (instant):lambert:tropopause:level 0:fcst time 0 hrs:from 201712010000
# 394:U component of wind:m s**-1 (instant):lambert:tropopause:level 0:fcst time 0 hrs:from 201712010000
# 395:V component of wind:m s**-1 (instant):lambert:tropopause:level 0:fcst time 0 hrs:from 201712010000
# 396:Pressure:Pa (instant):lambert:maxWind:level 0:fcst time 0 hrs:from 201712010000
# 397:U component of wind:m s**-1 (instant):lambert:maxWind:level 0:fcst time 0 hrs:from 201712010000
# 398:V component of wind:m s**-1 (instant):lambert:maxWind:level 0:fcst time 0 hrs:from 201712010000
# 399:Temperature:K (instant):lambert:heightAboveGround:level 80 m:fcst time 0 hrs:from 201712010000
# 400:Specific humidity:kg kg**-1 (instant):lambert:heightAboveGround:level 80 m:fcst time 0 hrs:from 201712010000
# 401:Pressure:Pa (instant):lambert:heightAboveGround:level 80 m:fcst time 0 hrs:from 201712010000
# 402:U component of wind:m s**-1 (instant):lambert:heightAboveGround:level 80 m:fcst time 0 hrs:from 201712010000
# 403:V component of wind:m s**-1 (instant):lambert:heightAboveGround:level 80 m:fcst time 0 hrs:from 201712010000
# 404:Geopotential Height:gpm (instant):lambert:isothermZero:level 0:fcst time 0 hrs:from 201712010000
# 405:Relative humidity:% (instant):lambert:isothermZero:level 0:fcst time 0 hrs:from 201712010000
# 406:Temperature:K (instant):lambert:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201712010000
# 407:Relative humidity:% (instant):lambert:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201712010000
# 408:U component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201712010000
# 409:V component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201712010000
# 410:Parcel lifted index (to 500 hPa):K (instant):lambert:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201712010000
# 411:Temperature:K (instant):lambert:pressureFromGroundLayer:levels 6000-3000 Pa:fcst time 0 hrs:from 201712010000
# 412:Relative humidity:% (instant):lambert:pressureFromGroundLayer:levels 6000-3000 Pa:fcst time 0 hrs:from 201712010000
# 413:U component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 6000-3000 Pa:fcst time 0 hrs:from 201712010000
# 414:V component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 6000-3000 Pa:fcst time 0 hrs:from 201712010000
# 415:Temperature:K (instant):lambert:pressureFromGroundLayer:levels 9000-6000 Pa:fcst time 0 hrs:from 201712010000
# 416:Relative humidity:% (instant):lambert:pressureFromGroundLayer:levels 9000-6000 Pa:fcst time 0 hrs:from 201712010000
# 417:U component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 9000-6000 Pa:fcst time 0 hrs:from 201712010000
# 418:V component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 9000-6000 Pa:fcst time 0 hrs:from 201712010000
# 419:Temperature:K (instant):lambert:pressureFromGroundLayer:levels 12000-9000 Pa:fcst time 0 hrs:from 201712010000
# 420:Relative humidity:% (instant):lambert:pressureFromGroundLayer:levels 12000-9000 Pa:fcst time 0 hrs:from 201712010000
# 421:U component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 12000-9000 Pa:fcst time 0 hrs:from 201712010000
# 422:V component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 12000-9000 Pa:fcst time 0 hrs:from 201712010000
# 423:Temperature:K (instant):lambert:pressureFromGroundLayer:levels 15000-12000 Pa:fcst time 0 hrs:from 201712010000
# 424:Relative humidity:% (instant):lambert:pressureFromGroundLayer:levels 15000-12000 Pa:fcst time 0 hrs:from 201712010000
# 425:U component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 15000-12000 Pa:fcst time 0 hrs:from 201712010000
# 426:V component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 15000-12000 Pa:fcst time 0 hrs:from 201712010000
# 427:Temperature:K (instant):lambert:pressureFromGroundLayer:levels 18000-15000 Pa:fcst time 0 hrs:from 201712010000
# 428:Relative humidity:% (instant):lambert:pressureFromGroundLayer:levels 18000-15000 Pa:fcst time 0 hrs:from 201712010000
# 429:U component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 18000-15000 Pa:fcst time 0 hrs:from 201712010000
# 430:V component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 18000-15000 Pa:fcst time 0 hrs:from 201712010000
# 431:Best (4-layer) lifted index:K (instant):lambert:pressureFromGroundLayer:levels 18000-0 Pa:fcst time 0 hrs:from 201712010000
# 432:Convective available potential energy:J kg**-1 (instant):lambert:pressureFromGroundLayer:levels 18000-0 Pa:fcst time 0 hrs:from 201712010000
# 433:Convective inhibition:J kg**-1 (instant):lambert:pressureFromGroundLayer:levels 18000-0 Pa:fcst time 0 hrs:from 201712010000
# 434:Planetary boundary layer height:m (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 435:Relative humidity:% (instant):lambert:sigmaLayer:levels 0.33-1.0 sigma value:fcst time 0 hrs:from 201712010000
# 436:Lightning:dimensionless (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 437:Land-sea mask:(0 - 1) (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 438:Sea-ice cover:(0 - 1) (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 439:Albedo:% (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 440:Sensible heat net flux:W m**-2 (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 441:Latent heat net flux:W m**-2 (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 442:Total Cloud Cover:% (instant):lambert:unknown:level 0 considered as a single layer:fcst time 0 hrs:from 201712010000
# 443:Downward short-wave radiation flux:W m**-2 (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 444:Downward long-wave radiation flux:W m**-2 (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 445:Upward short-wave radiation flux:W m**-2 (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000
# 446:Upward long-wave radiation flux:W m**-2 (instant):lambert:surface:level 0:fcst time 0 hrs:from 201712010000

# %%
# Code used to store the lattitude and longitude into a latslons.npy file for files before april 8th
grbs = pygrib.open("/mnt/data-weather/moddata/modgrb/namanl_218_20170101_0000_001.grb")
grb = grbs.select(name = "Temperature")[0] # selecting an arbitruary feature
data, lats, lons = grb.data(lat1 = 31, lat2 = 41, lon1 = -102, lon2 = -82) # cropping to domain
print("Data Shape: ", data.shape, 
      "Lat Shape: ", lats.shape, 
      "Lons Shape: ", lons.shape, 
      "Lats Min: ", lats.min(), 
      "Lons Min: ", lons.min(), 
      "Lats Max: ", lats.max(), 
      "Lons Max: ", lons.max())
#latslons = np.stack((lats, lons)) # latslons[0] = lats, latslons[1] = lons
#np.save("/mnt/data-weather/moddata/modnpy/latslons", latslons) # saving as .npy
grbs.close() # freeing up memory

# %%
# Code used to store the lattitude and longitude into a latslons.npy file for files after april 8th
grbs = pygrib.open("/mnt/data-weather/moddata/modgrb/namanl_218_20171201_0000_000.grb2")
grb = grbs.select(name = "Temperature")[0] # selecting an arbitruary feature
data, lats, lons = grb.data(lat1 = 31, lat2 = 41, lon1 = -102, lon2 = -82) # cropping to domain
print("Data Shape: ", data.shape, 
      "Lat Shape: ", lats.shape, 
      "Lons Shape: ", lons.shape, 
      "Lats Min: ", lats.min(), 
      "Lons Min: ", lons.min(), 
      "Lats Max: ", lats.max(), 
      "Lons Max: ", lons.max())
#latslons = np.stack((lats, lons)) # latslons[0] = lats, latslons[1] = lons
#np.save("/mnt/data-weather/moddata/modnpy/latslons", latslons) # saving as .npy
grbs.close() # freeing up memory

# %%
# Code used to get the stored lattitude and longitude in latslons.npy
#print(np.load("/mnt/data-weather/feature/latslons.npy").shape)
# lats is first row, lons is second row

# %%
# Code used to choose, extract, crop, and save the data into a ".npy" file
path_to_directory = "/mnt/data-weather/moddata/modgrb/"
path_to_save = "/mnt/data-weather/moddata/modnpy/temperature/"
feature = "Temperature"
directory = os.fsencode(path_to_directory)

for file in os.listdir(directory):
    filename = os.fsdecode(file) # Gets the filename of every file in "path_to_directory"
    grbs = pygrib.open(path_to_directory + filename) # Connects the path to the .grb file
    grb = grbs.select(name = feature)[0] # Gets the desired feature
    data, lats, lons = grb.data(lat1 = 31, lat2 = 41, lon1 = -102, lon2 = -82) # Crops the extracted data
    grbs.close() # freeing up memory
    rex = np.vstack((data, lats))
    rex = np.vstack((rex, lons))
    #print(filename[0:28])
    #print("Data: ", data.shape, data.min(), data.max()) 
    #print("Lats: ", lats.shape, lats.min(), lats.max())
    #print("Lons: ", lons.shape, lats.min(), lats.max())
    #print("Rex: ", rex)
    np.save(path_to_save + filename[0:28], rex) # saving as .npy
    
print("SUCCESS!")

# %%
# Code used to choose, extract, crop, and save the data into a ".npy" file
path_to_directory = "/mnt/data-weather/moddata/modgrb/"
path_to_save = "/mnt/data-weather/moddata/modnpy/relative-humidity/"
feature = "Relative humidity"
directory = os.fsencode(path_to_directory)

for file in os.listdir(directory):
    filename = os.fsdecode(file) # Gets the filename of every file in "path_to_directory"
    grbs = pygrib.open(path_to_directory + filename) # Connects the path to the .grb file
    grb = grbs.select(name = feature)[0] # Gets the desired feature
    data, lats, lons = grb.data(lat1 = 31, lat2 = 41, lon1 = -102, lon2 = -82) # Crops the extracted data
    grbs.close() # freeing up memory
    #rex = np.vstack((data, lats))
    #rex = np.vstack((rex, lons))
    print(filename[0:28])
    print("Data: ", data.shape, data.min(), data.max()) 
    #print("Lats: ", lats.shape, lats.min(), lats.max())
    #print("Lons: ", lons.shape, lats.min(), lats.max())
    #print("Rex: ", rex)
    #np.save(path_to_save + filename[0:28], rex) # saving as .npy
    
print("SUCCESS!")
# Out:
# namanl_218_20171229_1800_001
# Data:  (13999,) 2.0 5.0
# namanl_218_20171229_1800_002
# Data:  (13999,) 2.0 5.0
# namanl_218_20171229_1800_003
# Data:  (13999,) 2.0 5.0
# namanl_218_20171229_1800_006
# Data:  (13999,) 3.0 5.0
# namanl_218_20171230_0000_000
# Data:  (13999,) 2.0 6.0
# namanl_218_20171230_0000_001
# Data:  (13999,) 2.0 6.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-b896ddf69828> in <module>()
#       7 for file in os.listdir(directory):
#       8     filename = os.fsdecode(file) # Gets the filename of every file in "path_to_directory"
# ----> 9     grbs = pygrib.open(path_to_directory + filename) # Connects the path to the .grb file
#      10     grb = grbs.select(name = feature)[0] # Gets the desired feature
#      11     data, lats, lons = grb.data(lat1 = 31, lat2 = 41, lon1 = -102, lon2 = -82) # Crops the extracted data
#
# KeyboardInterrupt:

# %%
# Code used to choose, extract, crop, and save the data into a '.npy' file
path_to_directory = "/mnt/data-weather/moddata/"
path_to_save = "/mnt/data-weather/feature/total-cloud-cover/"
feature = "Total Cloud Cover"
index = 0
directory = os.fsencode(path_to_directory)

for file in os.listdir(directory):
    filename = os.fsdecode(file) # Gets the filename of every file in "path_to_directory"
    grbs = pygrib.open(path_to_directory + filename) # Connects the path to the .grb2 file
    grb = grbs.select(name = feature)[index] # Gets the desired feature
    data, lats, lons = grb.data(lat1 = 31, lat2 = 41, lon1 = -102, lon2 = -82) # Crops the extracted data
    #print(data.shape, lats.shape, lons.shape, lats.min(), lons.min(), lats.max(), lons.max())
    np.save(path_to_save + filename[0:-5], data) # getting rid of the .grb2 extension for .npy
    #print(feature, "of", path_to_save + filename, "saved successfully.")
    grbs.close()

# %%
# Code used to choose, extract, crop, and save the data into a '.npy' file
path_to_directory = "/mnt/data-weather/moddata/"
path_to_save = "/mnt/data-weather/feature/relative-humidity-2m/"
feature = "2 metre relative humidity"
index = 0
directory = os.fsencode(path_to_directory)

for file in os.listdir(directory):
    filename = os.fsdecode(file) # Gets the filename of every file in "path_to_directory"
    grbs = pygrib.open(path_to_directory + filename) # Connects the path to the .grb2 file
    grb = grbs.select(name = feature)[index] # Gets the desired feature
    data, lats, lons = grb.data(lat1 = 31, lat2 = 41, lon1 = -102, lon2 = -82) # Crops the extracted data
    #print(data.shape, lats.shape, lons.shape, lats.min(), lons.min(), lats.max(), lons.max())
    np.save(path_to_save + filename[0:-5], data) # getting rid of the .grb2 extension for .npy
    #print(feature, "of", path_to_save + filename, "saved successfully.")
    grbs.close()

# %%
grbs = pygrib.open("/mnt/data-weather/moddata/nam_218_20170101_1800_000.grb2")
for grb in grbs:
    print(grb)
grbs.close()

# %%
grbs = pygrib.open("/mnt/data-weather/moddata/nam_218_20170101_1800_000.grb2")
grb = grbs.select(name="2 metre relative humidity")[0]
print(grb)
data, lats, lons = grb.data(lat1 = 31, lat2 = 41, lon1 = -102, lon2 = -82)
print(data.shape)
print(type(data.max()))
