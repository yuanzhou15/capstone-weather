# %%
import matplotlib.pyplot as plt
import cv2 
import numpy as np

# %%
img = cv2.imread('/Users/Airton/Desktop/Data/B/012206B1.png')
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print('img.dtype: ', img.dtype)
# Out:
# img.dtype:  uint8

# %%
histr = cv2.calcHist([gray_img],[0],None,[256],[0,256])

# %%
plt.plot(histr) 
plt.show()

# %%
plt.hist(img.ravel(),50,[0,50]); plt.show()

# %%
th3 = cv2.threshold(gray_img,1,255,cv2.THRESH_BINARY)
print(type(th3))
# Out:
# <class 'tuple'>

# %%
plt.imshow(th3[1],cmap = 'gray')
plt.show()

# %%
plt.imshow(img,cmap = 'gray')
plt.show()
