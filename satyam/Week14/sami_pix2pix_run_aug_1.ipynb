# %%
from PIL import *
import numpy as np
import glob
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %%
original = glob.glob("../../augmented/runaug/1/results/weather/test_latest/images/*real*B.png")
original.sort()
original
# Out:
# ['../../augmented/runaug/1/results/weather/test_latest/images/010223A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/010303A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/012210A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/012218A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/012302A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/012305A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/021412A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/021500A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/022423A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/022814A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/022822A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/030122A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/030123A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/030200A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/030421A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/030621A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/030622A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/030623A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/030703A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/030711A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/031004A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/031005A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/031006A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/031322A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/031403A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032203A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032421A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032500A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032503A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032504A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032723A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032818A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032900A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032904A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032905A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032918A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032921A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/033003A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/033020A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/033101A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/040120A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/040122A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/040202A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/040212A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/040218A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/040308A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/040310A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/040313A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/040504A1_real_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/040507A1_real_B.png']

# %%
predicted = glob.glob("../../augmented/runaug/1/results/weather/test_latest/images/*fake*B.png")
predicted.sort()
predicted
# Out:
# ['../../augmented/runaug/1/results/weather/test_latest/images/010223A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/010303A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/012210A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/012218A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/012302A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/012305A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/021412A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/021500A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/022423A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/022814A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/022822A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/030122A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/030123A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/030200A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/030421A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/030621A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/030622A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/030623A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/030703A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/030711A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/031004A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/031005A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/031006A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/031322A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/031403A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032203A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032421A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032500A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032503A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032504A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032723A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032818A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032900A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032904A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032905A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032918A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/032921A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/033003A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/033020A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/033101A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/040120A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/040122A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/040202A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/040212A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/040218A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/040308A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/040310A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/040313A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/040504A1_fake_B.png',
#  '../../augmented/runaug/1/results/weather/test_latest/images/040507A1_fake_B.png']

# %%
def rmse(imageA, imageB):
    err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
    err /= float(imageA.shape[0] * imageA.shape[1])
    err = math.sqrt(err)
    return err

# %%
ssim_list = []
rmse_list = []

indexOf_least_rsme = 0;
least_rsme = 99999;
indexOf_largest_rsme = 0;
largest_rsme = 0;

for i in range(len(original)):
    print(predicted[i])
    print(original[i])
    fig=plt.figure()
    pred=np.asarray(Image.open(predicted[i]))
    real=np.asarray(Image.open(original[i]))
    plt.xlabel('Predicted', fontsize=20)
    plt.imshow(pred, cmap="gray")
    plt.show()
    plt.xlabel('Actual', fontsize=20)
    plt.imshow(real, cmap="gray")
    plt.show()
    rsme_ = rmse(pred, real)
    rmse_list.append(rsme_)
    print("RMSE: ", rsme_)
    
    if(rsme_ < least_rsme):
        least_rsme = rsme_
        indexOf_least_rsme = i
        
    if(rsme_ > largest_rsme):
        largest_rsme = rsme_
        indexOf_largest_rsme = i
        
        
    
    print("\n")
    print("=========================================")
# Out:
# ../../augmented/runaug/1/results/weather/test_latest/images/010223A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/010223A1_real_B.png
# RMSE:  95.43575886335383
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/010303A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/010303A1_real_B.png
# RMSE:  81.45319515586012
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/012210A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/012210A1_real_B.png
# RMSE:  105.94098467201619
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/012218A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/012218A1_real_B.png
# RMSE:  94.30792552858367
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/012302A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/012302A1_real_B.png
# RMSE:  71.10307341423572
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/012305A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/012305A1_real_B.png
# RMSE:  76.98214861540522
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/021412A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/021412A1_real_B.png
# RMSE:  89.49061398864927
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/021500A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/021500A1_real_B.png
# RMSE:  101.14390102522054
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/022423A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/022423A1_real_B.png
# RMSE:  66.0732698350425
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/022814A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/022814A1_real_B.png
# RMSE:  76.22867563705854
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/022822A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/022822A1_real_B.png
# RMSE:  79.67172465634717
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/030122A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/030122A1_real_B.png
# RMSE:  57.244613194134644
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/030123A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/030123A1_real_B.png
# RMSE:  66.69573346036766
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/030200A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/030200A1_real_B.png
# RMSE:  84.84169083093381
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/030421A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/030421A1_real_B.png
# RMSE:  35.44709575254423
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/030621A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/030621A1_real_B.png
# RMSE:  68.90636160705247
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/030622A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/030622A1_real_B.png
# RMSE:  74.2240182135186
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/030623A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/030623A1_real_B.png
# RMSE:  73.80131953850825
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/030703A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/030703A1_real_B.png
# RMSE:  76.23681336491008
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/030711A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/030711A1_real_B.png
# RMSE:  93.78498224282558
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/031004A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/031004A1_real_B.png
# RMSE:  87.61754190047584
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/031005A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/031005A1_real_B.png
# RMSE:  91.93824901573925
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/031006A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/031006A1_real_B.png
# RMSE:  97.68953300015353
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/031322A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/031322A1_real_B.png
# RMSE:  73.10958214616545
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/031403A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/031403A1_real_B.png
# RMSE:  63.61307388379619
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/032203A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/032203A1_real_B.png
# RMSE:  71.91837484099949
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/032421A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/032421A1_real_B.png
# RMSE:  86.88709246227458
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/032500A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/032500A1_real_B.png
# RMSE:  86.35525724292188
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/032503A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/032503A1_real_B.png
# RMSE:  94.36984081187379
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/032504A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/032504A1_real_B.png
# RMSE:  103.7279424176919
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/032723A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/032723A1_real_B.png
# RMSE:  76.56244519290131
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/032818A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/032818A1_real_B.png
# RMSE:  58.95796335416526
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/032900A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/032900A1_real_B.png
# RMSE:  96.66026059551854
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/032904A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/032904A1_real_B.png
# RMSE:  94.40078419505119
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/032905A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/032905A1_real_B.png
# RMSE:  96.72348439795803
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/032918A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/032918A1_real_B.png
# RMSE:  90.68181854686098
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/032921A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/032921A1_real_B.png
# RMSE:  70.57478781008467
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/033003A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/033003A1_real_B.png
# RMSE:  95.97770432013104
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/033020A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/033020A1_real_B.png
# RMSE:  80.03281454383942
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/033101A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/033101A1_real_B.png
# RMSE:  92.55492762179222
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/040120A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/040120A1_real_B.png
# RMSE:  58.96747804855848
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/040122A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/040122A1_real_B.png
# RMSE:  53.757470467866284
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/040202A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/040202A1_real_B.png
# RMSE:  67.95821678889152
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/040212A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/040212A1_real_B.png
# RMSE:  74.3573766008192
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/040218A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/040218A1_real_B.png
# RMSE:  68.99107104039464
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/040308A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/040308A1_real_B.png
# RMSE:  68.3253371731827
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/040310A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/040310A1_real_B.png
# RMSE:  85.70528142227802
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/040313A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/040313A1_real_B.png
# RMSE:  81.25615286198139
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/040504A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/040504A1_real_B.png
# RMSE:  85.85550465073867
#
#
# =========================================
# ../../augmented/runaug/1/results/weather/test_latest/images/040507A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/040507A1_real_B.png
# RMSE:  93.7744567708914
#
#
# =========================================

# %% [markdown]
# # Least RSME (Good)

# %%
fig=plt.figure()
pred=np.asarray(Image.open(predicted[indexOf_least_rsme]))
real=np.asarray(Image.open(original[indexOf_least_rsme]))
fig.suptitle('Least RSME (Good)', fontsize=30)

plt.xlabel('Predicted', fontsize=20)
plt.imshow(pred, cmap="gray")

plt.show()
print(predicted[indexOf_least_rsme])

print("\n\n")

plt.xlabel('Actual', fontsize=20)
plt.imshow(real, cmap="gray")

plt.show()
print(original[indexOf_least_rsme])

print("\n\n")

rsme_ = rmse(pred, real)

print("RMSE: ", rsme_)
# Out:
# ../../augmented/runaug/1/results/weather/test_latest/images/030421A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/030421A1_real_B.png
#
#
#
# RMSE:  35.44709575254423

# %% [markdown]
# # Largest RSME (Bad)

# %%
fig=plt.figure()
pred=np.asarray(Image.open(predicted[indexOf_largest_rsme]))
real=np.asarray(Image.open(original[indexOf_largest_rsme]))
fig.suptitle('Largest RSME (Bad)', fontsize=30)

plt.xlabel('Predicted', fontsize=20)
plt.imshow(pred, cmap="gray")

plt.show()
print(predicted[indexOf_largest_rsme])

print("\n\n")

plt.xlabel('Actual', fontsize=20)
plt.imshow(real, cmap="gray")

plt.show()
print(original[indexOf_largest_rsme])

print("\n\n")

rsme_ = rmse(pred, real)

print("RMSE: ", rsme_)
# Out:
# ../../augmented/runaug/1/results/weather/test_latest/images/012210A1_fake_B.png
# ../../augmented/runaug/1/results/weather/test_latest/images/012210A1_real_B.png
#
#
#
# RMSE:  105.94098467201619

# %%
len(original)
# Out:
# 50

# %%
len(rmse_list)
# Out:
# 0

# %%
x_axis = np.arange(len(original))
plt.scatter(x_axis, rmse_list)

# %% [markdown]
# # Confusion Matrix

# %%
real_flattened = []
pred_flattened = []

for i in range(len(original)):
    pred=np.asarray(Image.open(predicted[i])).flatten()
    real=np.asarray(Image.open(original[i])).flatten()
    pred_flattened.append(pred)
    real_flattened.append(real)
pred_flattened = np.array(pred_flattened).flatten()
real_flattened = np.array(real_flattened).flatten()

# %%
thershold = np.mean(real_flattened) + 1 * np.std(real_flattened)
thershold
# Out:
# 79.83512665705138

# %%
import scikitplot as skplt
y_train_copy = np.copy(real_flattened)
y_train_copy[y_train_copy < thershold] = 0
y_train_copy[y_train_copy >= thershold] = 1

predictions_train_copy = np.copy(pred_flattened)
predictions_train_copy[predictions_train_copy < thershold] = 0
predictions_train_copy[predictions_train_copy >= thershold] = 1

skplt.metrics.plot_confusion_matrix(y_train_copy, predictions_train_copy, normalize=True)
plt.show()

# %%
from sklearn.metrics import confusion_matrix
FPR = []
TPR = []

for i in range(1, np.max(real_flattened), 10):
    y_train_copy = np.copy(real_flattened)
    y_train_copy[y_train_copy < i] = 0
    y_train_copy[y_train_copy >= i] = 1

    predictions_train_copy = np.copy(pred_flattened)
    predictions_train_copy[predictions_train_copy < i] = 0
    predictions_train_copy[predictions_train_copy >= i] = 1
    
    temp = confusion_matrix(y_train_copy, predictions_train_copy)
    
    TN = temp[0][0]
    FP = temp[0][1]
    FN = temp[1][0]
    TP = temp[1][1]
    
    TPR_ = TP/(TP+FN)
    FPR_ = FP/(TN+FP)
    
    FPR.append(FPR_)
    TPR.append(TPR_)

# %%
plt.plot(FPR, TPR, label='ROC')
plt.plot([0,1], [0,1], linestyle='dashed')
plt.title("ROC Curve")
plt.xlabel("FPR")
plt.ylabel("TPR");
plt.legend()
